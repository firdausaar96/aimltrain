# %% [markdown]
# **Mini Project**
#
# Airline Tweet Sentiment Classifier Using Natural Language Processing
#
# **Notes:**
# Use sample dataset
#
# **Steps:**
#
#
# 1.   Import Libraries
# 2.   Load and explore dataset
# 3.   Clean and preprocess the text
# 4.    Convert Text to numerical vectors (TF-IDF)
# 5.    Split into train and test sets
# 6.    Train a Logistic Regression model
# 7.    Evaluate accuracy and classification report
# 8.    Predict sentiment for new example tweets

# %%
# Step 1a: Import Required Libraries

# %%
import pandas as pd
import re
import nltk
import string
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.linear_model import LogisticRegression

# %%
#Step 1b: Download nltk required

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#Step 2a: Load Dataset

# %%
df=pd.read_csv("/content/sample_data/airline_tweets_sample.csv")

# %%
#Step 2b: Check dataset at least 5 top values

# %%
df.head(5)
# Out:
#                                                 text sentiment
# 0  @United flight was delayed for 3 hours, worst ...  negative
# 1  Loved the service on @Delta, crew was super fr...  positive
# 2  @AmericanAir lost my luggage again, so disappo...  negative
# 3  Smooth boarding and on-time arrival. Great job...  positive
# 4  The seats were uncomfortable but staff was polite   neutral

# %%
#Step 3: Text Cleaning and Preprocessing
#For each tweet do:
#a) Convert to lowercase
#b) Remove URLs
#c) Remove Special character and numbers
#d) Remove stopwords (common words like the,is and)
#e) Apply stemming (reduce words to their root form)

# %%
df.isnull().sum()
# Out:
# text         0
# sentiment    0
# dtype: int64

# %%
def clean_text(text) :
  stemmer = PorterStemmer()
  text=text.lower()
  text=re.sub(r"http\S+","",text)
  text=re.sub(r"www\S+","",text)
  text=re.sub(r"[^a-z\s]","",text)
  text="".join([stemmer.stem(word) for word in text.split() if word not in stopwords.words("english")])
  return text

# %%
df["clean_text"]=df["text"].apply(clean_text)
df["clean_text"].head()
# Out:
# 0           unitflightdelayhourworstexperiever
# 1             loveservicdeltacrewsuperfriendli
# 2              americanairlostluggagdisappoint
# 3    smoothboardontimarrivgreatjobsouthwestair
# 4                      seatuncomfortstaffpolit
# Name: clean_text, dtype: object

# %%
#Step 4:
#a) Convert text to numerical vectors (TF-IDF)
#b) Check x,y and shape len

# %%
tfidf=TfidfVectorizer(max_features=5000, stop_words='english', sublinear_tf=True)
X = tfidf.fit_transform(df['clean_text'])
y = df['sentiment']

# %%
print("X :")
print(x)

print("\nShape of X:", x.shape)
print("Length of X:", len(x.toarray()))

print("\ny (labels):")
print(y)

print("Shape of y:", y.shape)
print("Length of y:", len(y))
# Out:
# X :
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 30 stored elements and shape (30, 30)>
#   Coords	Values
#   (0, 28)	1.0
#   (1, 16)	1.0
#   (2, 1)	1.0
#   (3, 22)	1.0
#   (4, 21)	1.0
#   (5, 14)	1.0
#   (6, 12)	1.0
#   (7, 2)	1.0
#   (8, 9)	1.0
#   (9, 13)	1.0
#   (10, 23)	1.0
#   (11, 24)	1.0
#   (12, 6)	1.0
#   (13, 8)	1.0
#   (14, 11)	1.0
#   (15, 26)	1.0
#   (16, 17)	1.0
#   (17, 0)	1.0
#   (18, 5)	1.0
#   (19, 20)	1.0
#   (20, 18)	1.0
#   (21, 15)	1.0
#   (22, 3)	1.0
#   (23, 19)	1.0
#   (24, 27)	1.0
#   (25, 10)	1.0
#   (26, 4)	1.0
#   (27, 7)	1.0
#   (28, 25)	1.0
#   (29, 29)	1.0
#
# Shape of X: (30, 30)
# Length of X: 30
#
# y (labels):
# 0     negative
# 1     positive
# 2     negative
# 3     positive
# 4      neutral
# 5     negative
# 6     positive
# 7      neutral
# 8     positive
# 9     negative
# 10    negative
# 11    positive
# 12    positive
# 13    negative
# 14     neutral
# 15    positive
# 16    negative
# 17    positive
# ...

# %%
#Step 5: Split into train and test sets
#80% training and 20% Testing

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#Step 6: Train a Logistic Regression model
#a) Create logistic model
#b) Train logistic Model

# %%
model=LogisticRegression(max_iter=1000)
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
#Step 7:
#Evaluate accuracy and classification report
#a) Predict Model
#b) Precision,recall, F1-Score for each sentiment

# %%
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
cnf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("Accuracy:", acc)
print("Confusion Matrix:\n", cnf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Accuracy: 0.16666666666666666
# Confusion Matrix:
#  [[1 0 0]
#  [1 0 0]
#  [4 0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#     negative       0.17      1.00      0.29         1
#      neutral       0.00      0.00      0.00         1
#     positive       0.00      0.00      0.00         4
#
#     accuracy                           0.17         6
#    macro avg       0.06      0.33      0.10         6
# weighted avg       0.03      0.17      0.05         6
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
#Step 8:Predict sentiment for new tweet

# %%
new_tweet=[
  "I had a fantastic flight with you! Everything was smooth and the service was excellent.",
    "My luggage is missing and your customer service is terrible. I will never fly this airline again.",
    "Flight 345 is delayed. Please provide an update on the gate change.",
    "Worst experience, ticket cancelled without notice. Avoid this airline."
]
new_clean_tweet=[clean_text(tweet) for tweet in new_tweet]
new_clean_tweet_tfidf=tfidf.transform(new_clean_tweet)
new_pred=model.predict(new_clean_tweet_tfidf)

print('\n Prediction are: ')
for tweet, new_pred in zip(new_tweet,new_pred):
  print(f" {tweet} --> {new_pred} ")
# Out:
#  Prediction are:
#  I had a fantastic flight with you! Everything was smooth and the service was excellent. --> negative
#  My luggage is missing and your customer service is terrible. I will never fly this airline again. --> negative
#  Flight 345 is delayed. Please provide an update on the gate change. --> negative
#  Worst experience, ticket cancelled without notice. Avoid this airline. --> negative
